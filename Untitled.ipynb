# %%
from pycaret.classification import *
import pandas as pd

# %%
versao = '_v1'
pre_tratamento = '_processado'
nome_alvo = 'Survived'

#Dados de entradas de treino
df = pd.read_csv('bases/train' + pre_tratamento + versao + '.csv')

# %%
df = df.drop('Ticket_num', axis = 1)

# %%
exp_clf = setup(df, target = 'Survived', numeric_features = df.drop('Survived', axis = 1).columns, normalize = True)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# #T_1b472ede_d6a6_11ea_87d7_28c2dd536ba8row4_col1,#T_1b472ede_d6a6_11ea_87d7_28c2dd536ba8row15_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_1b472ede_d6a6_11ea_87d7_28c2dd536ba8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b472ede_d6a6_11ea_87d7_28c2dd536ba8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1b472ede_d6a6_11ea_87d7_28c2dd536ba8row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_1b472ede_d6a6_11ea_87d7_28c2dd536ba8row0_col1" class="data row0 col1" >3719</td>
#             </tr>
#             <tr>
# ...

# %%
best_model = compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=176)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                19:59:11
# Status     . . . . . . . . . . . . . . . . . .    Fitting Fold 3 of 10
# Estimator  . . . . . . . . . . . . . . . . . .     CatBoost Classifier
# ETC        . . . . . . . . . . . . . . . . . .  3.06 Minutes Remaining
#                               Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0      Gradient Boosting Classifier    0.8267  0.8766  0.7321  0.8128  0.7622
# 1                  Ridge Classifier    0.8220  0.0000  0.7406  0.7946  0.7623
# 2            Extra Trees Classifier    0.8205  0.8710  0.7409  0.7860  0.7602
# 3         Extreme Gradient Boosting    0.8188  0.8601  0.7449  0.7867  0.7590
# 4          Random Forest Classifier    0.8172  0.8493  0.6987  0.8078  0.7455
# 5      Linear Discriminant Analysis    0.8140  0.8363  0.7447  0.7713  0.7541
# 6   Light Gradient Boosting Machine    0.8124  0.8612  0.7409  0.7756  0.7526
# ...

# %%
dt = create_model('gbc', normalize = True)
# Out:
# <style  type="text/css" >
# #T_20dd1dd8_d6a3_11ea_9445_28c2dd536ba8row10_col0,#T_20dd1dd8_d6a3_11ea_9445_28c2dd536ba8row10_col1,#T_20dd1dd8_d6a3_11ea_9445_28c2dd536ba8row10_col2,#T_20dd1dd8_d6a3_11ea_9445_28c2dd536ba8row10_col3,#T_20dd1dd8_d6a3_11ea_9445_28c2dd536ba8row10_col4,#T_20dd1dd8_d6a3_11ea_9445_28c2dd536ba8row10_col5,#T_20dd1dd8_d6a3_11ea_9445_28c2dd536ba8row10_col6{
#             background:  yellow;
#         }</style><table id="T_20dd1dd8_d6a3_11ea_9445_28c2dd536ba8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
plot_model(dt)

# %%
plot_model(dt, plot = 'feature')

# %%
interpret_model(aa)

# %%
aa = tune_model(dt)
# Out:
# <style  type="text/css" >
# #T_69671a50_d6a3_11ea_809a_28c2dd536ba8row10_col0,#T_69671a50_d6a3_11ea_809a_28c2dd536ba8row10_col1,#T_69671a50_d6a3_11ea_809a_28c2dd536ba8row10_col2,#T_69671a50_d6a3_11ea_809a_28c2dd536ba8row10_col3,#T_69671a50_d6a3_11ea_809a_28c2dd536ba8row10_col4,#T_69671a50_d6a3_11ea_809a_28c2dd536ba8row10_col5,#T_69671a50_d6a3_11ea_809a_28c2dd536ba8row10_col6{
#             background:  yellow;
#         }</style><table id="T_69671a50_d6a3_11ea_809a_28c2dd536ba8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
save_model(dt, model_name='best-model')
# Out:
# INFO:logs:Initializing save_model()
# INFO:logs:save_model(model=ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=416, verbose=0,
#                      warm_start=False), model_name=best-model, verbose=True)
# INFO:logs:Appending prep pipeline
# INFO:logs:best-model.pkl saved in current working directory
# INFO:logs:[Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
# ...

# %%
df = df.astype(float)

# %%
df['Survived'] = df['Survived'].astype(int)
